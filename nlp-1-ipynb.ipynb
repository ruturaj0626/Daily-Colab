# %%
review = "'Avtaar' is a heartwarming family drama that explores the struggles of a middle-class family in India. Directed by Mohan Kumar, the film features Rajesh Khanna in the lead role of Avtaar Krishen, a middle-aged man who has devoted his entire life to his family and their well-being. The film begins by introducing us to Avtaar, a hardworking man who has always put the needs of his family before his own. Despite his efforts, Avtaar struggles to make ends meet and provide a better life for his family. However, he remains optimistic and determined to provide for his loved ones. As the story unfolds, we see Avtaar facing various challenges, including financial difficulties, familial conflicts, and health problems. However, he never loses hope and remains steadfast in his love and commitment towards his family. The film beautifully portrays the struggles and sacrifices of a middle-class man in India and highlights the importance of family values and relationships. Rajesh Khanna delivers a remarkable performance as Avtaar, bringing his character to life with sincerity and depth. He portrays the role of a selfless, hardworking, and caring family man with ease, making the audience empathize with his character's struggles and root for his success. The supporting cast, including Shabana Azmi, Sachin Pilgaonkar, and A.K. Hangal, also deliver strong performances, adding to the film's emotional depth and impact. The film's direction, screenplay, and music are also noteworthy. Mohan Kumar's direction is sensitive and effective, bringing out the best in the film's cast and crew. The screenplay by Sachin Bhowmick is engaging and well-paced, keeping the audience hooked from start to finish. The music by Laxmikant-Pyarelal is memorable, with several iconic songs such as 'Dekha Ek Khwab' and 'Tere Chehre Se Nazar Nahin'. Overall, 'Avtaar' is a classic Bollywood film that showcases the power of family bonds and the resilience of the human spirit. It is a must-watch for fans of Indian cinema and anyone who appreciates heartfelt family dramas. The film's themes and messages remain relevant even today, making it a timeless classic that can be enjoyed by audiences of all ages."

# %%
review
# Out:
# "'Avtaar' is a heartwarming family drama that explores the struggles of a middle-class family in India. Directed by Mohan Kumar, the film features Rajesh Khanna in the lead role of Avtaar Krishen, a middle-aged man who has devoted his entire life to his family and their well-being. The film begins by introducing us to Avtaar, a hardworking man who has always put the needs of his family before his own. Despite his efforts, Avtaar struggles to make ends meet and provide a better life for his family. However, he remains optimistic and determined to provide for his loved ones. As the story unfolds, we see Avtaar facing various challenges, including financial difficulties, familial conflicts, and health problems. However, he never loses hope and remains steadfast in his love and commitment towards his family. The film beautifully portrays the struggles and sacrifices of a middle-class man in India and highlights the importance of family values and relationships. Rajesh Khanna delivers a r
# ...

# %% [markdown]
# ## 1. Tokenization
# >> braking into smaller packets. sentence tokenization or word tokenization

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize

# %%
tokens = word_tokenize(review)
print(tokens)
# Out:
# ["'Avtaar", "'", 'is', 'a', 'heartwarming', 'family', 'drama', 'that', 'explores', 'the', 'struggles', 'of', 'a', 'middle-class', 'family', 'in', 'India', '.', 'Directed', 'by', 'Mohan', 'Kumar', ',', 'the', 'film', 'features', 'Rajesh', 'Khanna', 'in', 'the', 'lead', 'role', 'of', 'Avtaar', 'Krishen', ',', 'a', 'middle-aged', 'man', 'who', 'has', 'devoted', 'his', 'entire', 'life', 'to', 'his', 'family', 'and', 'their', 'well-being', '.', 'The', 'film', 'begins', 'by', 'introducing', 'us', 'to', 'Avtaar', ',', 'a', 'hardworking', 'man', 'who', 'has', 'always', 'put', 'the', 'needs', 'of', 'his', 'family', 'before', 'his', 'own', '.', 'Despite', 'his', 'efforts', ',', 'Avtaar', 'struggles', 'to', 'make', 'ends', 'meet', 'and', 'provide', 'a', 'better', 'life', 'for', 'his', 'family', '.', 'However', ',', 'he', 'remains', 'optimistic', 'and', 'determined', 'to', 'provide', 'for', 'his', 'loved', 'ones', '.', 'As', 'the', 'story', 'unfolds', ',', 'we', 'see', 'Avtaar', 'facing', 'vario
# ...

# %% [markdown]
# ## 2. Remove Punctuations

# %%
len(tokens)
# Out:
# 402

# %%
from string import punctuation
# using list compreshension

clean_tokens = [tokens for tokens in tokens if tokens not in punctuation]
len(clean_tokens)
# Out:
# 353

# %% [markdown]
# ## 3. Stopwords

# %%
from nltk.corpus import stopwords
# common words which repeat and dont have much say for the sentence

# %%
stop_list = stopwords.words('english')
print(stop_list)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
clean_tokens = [ tokens for tokens in clean_tokens if tokens not in stop_list ]
len(clean_tokens)
# Out:
# 227

# %%
import re
import string

# %%
def preprocess_text(text):
    # Convert the text to lowercase
    text = text.lower()
    
    # Remove numbers
    text = re.sub(r'\d+', '', text)
    
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    
    # Tokenize the text
    tokens = word_tokenize(text)
    
    # Remove stop words
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]
    
    
    # Join the tokens back into a string
    text = ' '.join(tokens)
    
    return text

# %%
review2 = preprocess_text(review)

# %% [markdown]
# ## WordCloud Visualization

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
wordcloud = WordCloud(width = 800, height = 800, 
                      background_color ='black', 
                      stopwords = set(stopwords.words('english')), 
                      min_font_size = 10).generate(review2)

# %%
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()

# %% [markdown]
# ## Named Entity Recogniion

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')
doc1 = nlp(review2)

# %%
review2
# Out:
# 'avtaar heartwarming family drama explores struggles middleclass family india directed mohan kumar film features rajesh khanna lead role avtaar krishen middleaged man devoted entire life family wellbeing film begins introducing us avtaar hardworking man always put needs family despite efforts avtaar struggles make ends meet provide better life family however remains optimistic determined provide loved ones story unfolds see avtaar facing various challenges including financial difficulties familial conflicts health problems however never loses hope remains steadfast love commitment towards family film beautifully portrays struggles sacrifices middleclass man india highlights importance family values relationships rajesh khanna delivers remarkable performance avtaar bringing character life sincerity depth portrays role selfless hardworking caring family man ease making audience empathize characters struggles root success supporting cast including shabana azmi sachin pilgaonkar ak hanga
# ...

# %%
for ent in doc1.ents:
    print(ent.text,ent.label_)
# Out:
# india GPE
# mohan kumar PERSON
# khanna PERSON
# india GPE
# khanna ORG
# shabana ORG
# pilgaonkar GPE
# ek khwab PERSON
# chehre se PERSON
# indian NORP
# appreciates heartfelt PERSON
# today DATE
